# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Generate a random input dataframe
np.random.seed(0)
df = pd.DataFrame({'x': np.random.rand(8)})

# Calculate the FFT of the dataframe using numpy
X = np.fft.fft(df['x'].values)

# Define the size of each marker based on the magnitude of each element in the dataframe
sizes = np.abs(df['x'].values) * 200

plt.scatter(df.index, df['x'], c=df['x'], cmap='hsv', s=sizes, alpha=0.5618033)
plt.title("Input Dataframe")
plt.xlabel("Index")
plt.ylabel("Value")
plt.colorbar()
plt.show()

magnitude = np.abs(X)
phase = np.angle(X)

plt.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=0.5618033)
plt.title("FFT of Dataframe")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
plt.colorbar()
plt.show()

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Define a function to generate Fibonacci numbers
def fibonacci(n):
    fib_sequence = [0, 1]
    while len(fib_sequence) < n:
        fib_sequence.append(fib_sequence[-1] + fib_sequence[-2])
    return fib_sequence

# Generate Fibonacci numbers
n_fib = 55  # Change this value to generate more or fewer Fibonacci numbers
fib_numbers = fibonacci(n_fib)

# Create a DataFrame from Fibonacci numbers
df = pd.DataFrame({'x': fib_numbers})

# Calculate the FFT of the dataframe using numpy
X = np.fft.fft(df['x'].values)

# Define the size of each marker based on the magnitude of each element in the dataframe
sizes = np.abs(df['x'].values) * 0.000000000000000000000005

# Calculate magnitude and phase of FFT output
magnitude = np.abs(X)
phase = np.angle(X)

# Plot the FFT output using scatter plot
plt.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=0.5618033)
plt.title("FFT of Fibonacci Numbers")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
plt.colorbar(label='Phase')
plt.show()

# %%
#Optimized version
import numpy as np
import pandas as pd

# Generate a random input dataframe
np.random.seed(55)
df = pd.DataFrame({'x': np.random.rand(144)})

# Calculate the FFT of the dataframe using numpy
X = np.fft.fft(df['x'].values)

import matplotlib.pyplot as plt

# Define the size of each marker based on the magnitude of each element in the dataframe
sizes = np.abs(df['x'].values) * 200

magnitude = np.abs(X)
phase = np.angle(X)

plt.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=0.5318033)
plt.title("FFT of Dataframe")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
plt.colorbar()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Define a function to generate Fibonacci numbers
def fibonacci(n):
    fib_sequence = [0, 1]
    while len(fib_sequence) < n:
        fib_sequence.append(fib_sequence[-1] + fib_sequence[-2])
    return fib_sequence[:n]  # Return only the first n Fibonacci numbers

# Generate a random number of Fibonacci numbers
np.random.seed(55)  # For reproducibility
n_fib = np.random.randint(5, 144)  # Random number of Fibonacci numbers between 5 and 144
fib_numbers = fibonacci(n_fib)

# Create a DataFrame from Fibonacci numbers
df = pd.DataFrame({'x': fib_numbers})

# Calculate the FFT of the dataframe using numpy
X = np.fft.fft(df['x'].values)

# Define the size of each marker based on the magnitude of each element in the dataframe
sizes = np.abs(df['x'].values) * 0.000000000111
# Calculate magnitude and phase of FFT output
magnitude = np.abs(X)
phase = np.angle(X)

# Plot the FFT output using scatter plot
plt.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=0.5318033)
plt.title("FFT of Random Fibonacci Numbers")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
plt.colorbar(label='Phase')
plt.grid()
plt.show()

# %%
import random

def generate_fibonacci(x, y):
    # Generate Fibonacci numbers until the last number exceeds y
    fib_sequence = [0, 1]
    while True:
        next_fib = fib_sequence[-1] + fib_sequence[-2]
        if next_fib > y:
            break
        fib_sequence.append(next_fib)

    # Filter the Fibonacci numbers to only include those between x and y
    filtered_fibs = [num for num in fib_sequence if x <= num <= y]

    # Randomly select a subset of Fibonacci numbers to return
    if filtered_fibs:
        random_count = random.randint(1, len(filtered_fibs))  # Random count of Fibonacci numbers to return
        return random.sample(filtered_fibs, random_count)
    else:
        return []  # Return an empty list if no Fibonacci numbers are found in the range

# Example usage
x = 0
y = 10000000000
random_fibonacci_numbers = generate_fibonacci(x, y)
print(random_fibonacci_numbers)
# Out:
# [28657, 21, 9227465, 89, 6765, 4807526976, 2584, 39088169, 433494437, 17711, 63245986, 8, 3, 14930352, 165580141, 7778742049, 75025, 267914296, 24157817, 196418, 1134903170, 55, 121393, 3524578, 5, 377, 1597, 4181, 514229, 987, 701408733, 102334155, 34, 13, 832040, 2, 46368]

# %%
import random

def generate_fibonacci(x, y, z):
    # Generate Fibonacci numbers until the last number exceeds y
    fib_sequence = [0, 1]
    while True:
        next_fib = fib_sequence[-1] + fib_sequence[-2]
        if next_fib > y:
            break
        fib_sequence.append(next_fib)

    # Filter the Fibonacci numbers to only include those between x and y
    filtered_fibs = [num for num in fib_sequence if x <= num <= y]

    # Ensure the output list has exactly z elements
    if filtered_fibs:
        # Randomly select a subset of Fibonacci numbers to return
        if len(filtered_fibs) >= z:
            return random.sample(filtered_fibs, z)  # Return a random sample of size z
        else:
            # If there are fewer than z Fibonacci numbers, fill the list with the same values
            return random.choices(filtered_fibs, k=z)  # Allows repetition to fill up to z
    else:
        return [0] * z  # Return a list of zeros if no Fibonacci numbers are found

# Example usage
x = 0
y = 100000000000
z = 100  # Desired size of the output list
random_fibonacci_numbers = generate_fibonacci(x, y, z)
print(random_fibonacci_numbers)
# Out:
# [2971215073, 610, 63245986, 144, 2971215073, 514229, 267914296, 1836311903, 14930352, 267914296, 102334155, 1836311903, 5, 10946, 21, 8, 1346269, 3524578, 1, 1134903170, 34, 514229, 34, 2584, 12586269025, 2584, 53316291173, 12586269025, 5702887, 233, 1, 832040, 233, 144, 55, 5, 3, 32951280099, 46368, 5, 20365011074, 4807526976, 53316291173, 7778742049, 1, 17711, 6765, 14930352, 1, 3, 34, 8, 17711, 0, 144, 7778742049, 2178309, 1836311903, 5702887, 89, 196418, 75025, 1134903170, 144, 75025, 102334155, 10946, 987, 24157817, 987, 46368, 2584, 5702887, 3524578, 433494437, 233, 1597, 14930352, 1, 1836311903, 46368, 987, 4181, 832040, 1597, 14930352, 63245986, 0, 21, 28657, 20365011074, 701408733, 63245986, 53316291173, 20365011074, 28657, 317811, 2178309, 2971215073, 10946]

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Function to generate Fibonacci numbers within a specified range
def generate_fibonacci(x, y, z):
    # Generate Fibonacci numbers until the last number exceeds y
    fib_sequence = [0, 1]
    while True:
        next_fib = fib_sequence[-1] + fib_sequence[-2]
        if next_fib > y:
            break
        fib_sequence.append(next_fib)

    # Filter the Fibonacci numbers to only include those between x and y
    filtered_fibs = [num for num in fib_sequence if x <= num <= y]

    # Ensure the output list has exactly z elements
    if filtered_fibs:
        # Randomly select a subset of Fibonacci numbers to return
        if len(filtered_fibs) >= z:
            return random.sample(filtered_fibs, z)  # Return a random sample of size z
        else:
            # If there are fewer than z Fibonacci numbers, fill the list with the same values
            return random.choices(filtered_fibs, k=z)  # Allows repetition to fill up to z
    else:
        return [0] * z  # Return a list of zeros if no Fibonacci numbers are found

# Example usage
x = 0
y = 10000000
z = 10000  # Desired size of the output list
random_fibonacci_numbers = generate_fibonacci(x, y, z)

# Create a DataFrame from the generated Fibonacci numbers
df = pd.DataFrame({'x': random_fibonacci_numbers})

# Calculate the FFT of the dataframe using numpy
X = np.fft.fft(df['x'].values)

# Define the size of each marker based on the magnitude of each element in the dataframe
sizes =  5.0000000000000000000000000001618033

# Calculate magnitude and phase of FFT output
magnitude = np.abs(X)
phase = np.angle(X)

# Plot the FFT output using scatter plot
plt.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=0.5318033)
plt.title("FFT of Random Fibonacci Numbers")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
plt.colorbar(label='Phase')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.fft import fft


def fibonacci(n):
    fib_sequence = [0, 1]
    for i in range(2, n):
        next_fib = fib_sequence[-1] + fib_sequence[-2]
        fib_sequence.append(next_fib)
    return fib_sequence

n = 99
fib_numbers = fibonacci(n)

# Generate a random array containing Fibonacci numbers
random_fib_numbers = np.random.choice(fib_numbers, size=n)

# Create a DataFrame from the random Fibonacci numbers
df = pd.DataFrame({'x': random_fib_numbers})

# Calculate the FFT of the dataframe using scipy.fft
X = fft(df['x'].values)

# Define the size of each marker based on the magnitude of each element in the FFT result
sizes = np.abs(X) * 0.00000000000000000061803398874988

plt.scatter(df.index, df['x'], c=df['x'], cmap='hsv', s=sizes, alpha=0.5)
plt.title("Input Dataframe")
plt.xlabel("Index")
plt.ylabel("Value")
plt.colorbar()
plt.show()

magnitude = np.abs(X)
phase = np.angle(X)

plt.scatter(np.real(X), np.imag(X), c=phase, cmap='hsv', s=sizes, alpha=0.314)
plt.title("FFT of Dataframe")
plt.xlabel("Real Part")
plt.ylabel("Imaginary Part")
plt.colorbar()
plt.show()
